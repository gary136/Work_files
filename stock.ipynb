# %%
import requests
from io import StringIO
import pandas as pd
import numpy as np

# %%
datestr = '20180131'
r = requests.post('http://www.twse.com.tw/exchangeReport/MI_INDEX?response=csv&date=' + datestr + '&type=ALL')

# %%
df = pd.read_csv(StringIO("\n".join([i.translate({ord(c): None for c in ' '}) 
                                     for i in r.text.split('\n') 
                                     if len(i.split('",')) == 17 and i[0] != '='])), header=0)

# %%
df
# Out:
#      證券代號     證券名稱        成交股數   成交筆數           成交金額     開盤價     最高價     最低價  \
# 0    1101       台泥   5,410,009  1,594    203,905,328   37.60   37.90   37.35
# 1    1102       亞泥   5,133,744  2,252    153,286,235   29.70   30.30   29.50
# 2    1103       嘉泥     231,313    105      3,113,671   13.45   13.55   13.40
# 3    1104       環泥     202,209    146      4,612,469   22.80   22.90   22.75
# 4    1108       幸福     109,000     51        919,930    8.49    8.54    8.40
# 5    1109       信大      63,112     43        869,184   13.80   13.85   13.70
# 6    1110       東泥     485,000     32      6,790,400   14.00   14.05   14.00
# 7    1201       味全   1,319,243    612     30,894,701   23.40   23.65   23.10
# 8    1203       味王      58,961     49      1,566,608   26.20   26.85   26.20
# 9    1210       大成     644,641    436     21,881,063   33.90   34.15   33.80
# 10   1213       大飲      17,002     12        270,880   15.95   16.00   15.80
# ...

# %%
t = StringIO("\n".join([i.translate({ord(c): None for c in ' '}) 
                                     for i in r.text.split('\n') 
                                     if len(i.split('",')) == 17 and i[0] != '=']))

# %%
next(t)
# Out:
# '"1103","嘉泥","231,313","105","3,113,671","13.45","13.55","13.40","13.55","-","0.05","13.50","6","13.55","5","84.69",\r\n'

# %%
print(len([i for i in r.text.split('\n')]))
print(len([i for i in r.text.split('\n') if len(i.split('",')) == 17]))
print(len([i for i in r.text.split('\n') if len(i.split('",')) == 17 and i[0] != '=']))
# Out:
# 13882
# 13724
# 935

# %%
data = [i for i in r.text.split('\n') if len(i.split('",')) == 17 and i[0] != '=']

# %%
tes = data[4]

# %%
new_data = list(map(lambda x:x.translate({ord(c): None for c in ' '}), data))
for i in range(len(data)):
    if data[i] != new_data[i]:
        print(data[i], '\n', len(data[i]), '\n', new_data[i], '\n', len(new_data[i]))
# Out:
# "1104","環泥","202,209","146","4,612,469","22.80","22.90","22.75","22.85"," ","0.00","22.80","26","22.85","18","9.89",
#  117
#  "1104","環泥","202,209","146","4,612,469","22.80","22.90","22.75","22.85","","0.00","22.80","26","22.85","18","9.89",
#  116
# "1108","幸福","109,000","51","919,930","8.49","8.54","8.40","8.49"," ","0.00","8.44","5","8.49","4","53.06",
#  107
#  "1108","幸福","109,000","51","919,930","8.49","8.54","8.40","8.49","","0.00","8.44","5","8.49","4","53.06",
#  106
# "1213","大飲","17,002","12","270,880","15.95","16.00","15.80","16.00"," ","0.00","15.85","2","16.05","4","114.29",
#  113
#  "1213","大飲","17,002","12","270,880","15.95","16.00","15.80","16.00","","0.00","15.85","2","16.05","4","114.29",
#  112
# "1219","福壽","10,246","19","180,574","17.60","17.70","17.60","17.70"," ","0.00","17.65","1","17.70","2","61.03",
#  112
#  "1219","福壽","10,246","19","180,574","17.60","17.70","17.60","17.70","","0.00","17.65","1","17.70","2","61.03",
#  111
# ...

# %%
[i for i in r.text.split('\n')]
# Out:
# ['"107年01月31日 大盤統計資訊"\r',
#  '"指數","收盤指數","漲跌(+/-)","漲跌點數","漲跌百分比(%)",\r',
#  '"寶島股價指數","12,784.38","+","33.27","0.26",\r',
#  '"發行量加權股價指數","11,103.79","+","27.01","0.24",\r',
#  '"臺灣公司治理100指數","6,330.44","+","17.41","0.28",\r',
#  '"臺灣50指數","8,420.43","+","23.45","0.28",\r',
#  '"臺灣中型100指數","8,012.90","+","28.00","0.35",\r',
#  '"臺灣資訊科技指數","11,090.30","+","59.16","0.54",\r',
#  '"臺灣發達指數","8,817.78","-","5.99","-0.07",\r',
#  '"臺灣高股息指數","6,204.32","+","9.32","0.15",\r',
#  '"臺灣永續指數","5,431.29","+","13.04","0.24",\r',
#  '"臺灣就業99指數","6,561.11","+","14.53","0.22",\r',
#  '"臺灣高薪100指數","6,128.26","+","9.56","0.16",\r',
#  '"臺灣低波動高股息指數","1,584.51","+","3.45","0.22",\r',
#  '"未含金融保險股指數","9,432.94","+","20.02","0.21",\r',
#  '"未含電子股指數","14,901.79","+","29.40","0.20",\r',
#  '"未含金融電子股指數","12,739.35","+","11.82","0.09",\r',
#  '"小型股300指數","6,496.37","+","9.04","0.14",\r',
#  '"漲升股利150指數","6,202.16","+","4.49","0.07",\r',
#  '"漲升股利100指數","6,177.88","+","4.33","0.07",\r',
# ...

# %%
data = [i for i in r.text.split('\n') if len(i.split('",')) == 17 and i[0] != '=']

# %%
from string import maketrans   # Required to call maketrans function.

intab = "aeiou"
outtab = "12345"
trantab = maketrans(intab, outtab)

t = "this is string example....wow!!!";
print(t.translate(trantab))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-dec99e32f59d> in <module>()
# ----> 1 from string import maketrans   # Required to call maketrans function.
#       2
#       3 intab = "aeiou"
#       4 outtab = "12345"
#       5 trantab = maketrans(intab, outtab)
#
# ImportError: cannot import name 'maketrans'

# %%
str(5)
# Out:
# '5'

# %%
print(len(tes))
print(len(tes.translate({ord(c): None for c in ' '})))
print(len(tes.replace(' ', '')))
# Out:
# 117
# 116
# 116

# %%
tes
# Out:
# '"1104","環泥","202,209","146","4,612,469","22.80","22.90","22.75","22.85"," ","0.00","22.80","26","22.85","18","9.89",\r'

# %% [markdown]
# # translate

# %%
'12345'.translate({ord(c):None for c in '123'})
# Out:
# '45'

# %%
'12345'.translate({ord('1'):ord('a')})
# Out:
# 'a2345'

# %%
'12345'.translate({ord('1'):'a'})
# Out:
# 'a2345'

# %%
table = 'iii'.maketrans('abcde', '12345')
sentence = 'this is a guava'
sentence.translate(table)
# Out:
# 'this is 1 gu1v1'

# %%
from str import maketrans
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-d98df668f2a5> in <module>()
# ----> 1 from str import maketrans
#
# ModuleNotFoundError: No module named 'str'

# %%
'this is a guava'.maketrans('abcde', '12345')
# Out:
# {97: 49, 98: 50, 99: 51, 100: 52, 101: 53}

# %%
''.maketrans('abcde', '12345')
# Out:
# {97: 49, 98: 50, 99: 51, 100: 52, 101: 53}

# %%
''.maketrans(' ', '')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-0e09a2d96a6c> in <module>()
# ----> 1 ''.maketrans(' ', '')
#
# ValueError: the first two maketrans arguments must have equal length

# %%
help(str.maketrans)
# Out:
# Help on built-in function maketrans:
#
# maketrans(x, y=None, z=None, /)
#     Return a translation table usable for str.translate().
#
#     If there is only one argument, it must be a dictionary mapping Unicode
#     ordinals (integers) or characters to Unicode ordinals, strings or None.
#     Character keys will be then converted to ordinals.
#     If there are two arguments, they must be strings of equal length, and
#     in the resulting dictionary, each character in x will be mapped to the
#     character at the same position in y. If there is a third argument, it
#     must be a string, whose characters will be mapped to None in the result.

# %%
help(str.translate)
# Out:
# Help on method_descriptor:
#
# translate(...)
#     S.translate(table) -> str
#
#     Return a copy of the string S in which each character has been mapped
#     through the given translation table. The table must implement
#     lookup/indexing via __getitem__, for instance a dictionary or list,
#     mapping Unicode ordinals to Unicode ordinals, strings, or None. If
#     this operation raises LookupError, the character is left untouched.
#     Characters mapped to None are deleted.

# %%
'abcde'.translate({97: 49, 98: 50, 99: 51, 100: 52, 101: 53})
# Out:
# '12345'

# %% [markdown]
# # modify

# %%
data = [i.replace(' ', '')
        for i in r.text.split('\n')
        if len(i.split('",')) == 17 and i[0] != '=']

# %%
merge_data = "\n".join(data)

# %%
df = pd.read_csv(StringIO(merge_data))

# %%
df
# Out:
#      證券代號     證券名稱        成交股數   成交筆數           成交金額     開盤價     最高價     最低價  \
# 0    1101       台泥   5,410,009  1,594    203,905,328   37.60   37.90   37.35
# 1    1102       亞泥   5,133,744  2,252    153,286,235   29.70   30.30   29.50
# 2    1103       嘉泥     231,313    105      3,113,671   13.45   13.55   13.40
# 3    1104       環泥     202,209    146      4,612,469   22.80   22.90   22.75
# 4    1108       幸福     109,000     51        919,930    8.49    8.54    8.40
# 5    1109       信大      63,112     43        869,184   13.80   13.85   13.70
# 6    1110       東泥     485,000     32      6,790,400   14.00   14.05   14.00
# 7    1201       味全   1,319,243    612     30,894,701   23.40   23.65   23.10
# 8    1203       味王      58,961     49      1,566,608   26.20   26.85   26.20
# 9    1210       大成     644,641    436     21,881,063   33.90   34.15   33.80
# 10   1213       大飲      17,002     12        270,880   15.95   16.00   15.80
# ...

# %%
def crawl_price(date):
    base = 'http://www.twse.com.tw/exchangeReport/MI_INDEX?response=csv&date={}&type=ALL'
    r = requests.post(base.format(str(date).split(' ')[0].replace('-','')))
    filtered = [i.replace(' ', '')
            for i in r.text.split('\n')
            if len(i.split('",')) == 17 and i[0] != '=']
    merge_data = "\n".join(filtered)
    ret = pd.read_csv(StringIO(merge_data))
    ret = ret.set_index('證券代號')
    ret.drop(['Unnamed: 16', '最後揭示買價', '最後揭示買量', '最後揭示賣價', '最後揭示賣量'], axis = 1, inplace = True)
    def str_num(x):
        if '.' in x:
            num_x = float(x.replace(',',''))
        else:
            num_x = int(x.replace(',',''))
        return num_x
    for i in ['成交股數', '成交筆數', '成交金額', '本益比']:
        try:
            ret[i] = ret[i].apply(str_num)
        except:
            print('some transform fails')
    return ret

# %%
df = crawl_price('20181011')

# %%
[i for i in df[['開盤價', '最高價', '最低價', '收盤價', '漲跌價差']]['開盤價'] if '-' in i]
# Out:
# ['--', '--', '--', '--', '--', '--', '--']

# %%
df.columns
# Out:
# Index(['證券名稱', '成交股數', '成交筆數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌(+/-)',
#        '漲跌價差', '本益比'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 937 entries, 1101 to 9958
# Data columns (total 11 columns):
# 證券名稱       937 non-null object
# 成交股數       937 non-null int64
# 成交筆數       937 non-null int64
# 成交金額       937 non-null int64
# 開盤價        937 non-null object
# 最高價        937 non-null object
# 最低價        937 non-null object
# 收盤價        937 non-null object
# 漲跌(+/-)    922 non-null object
# 漲跌價差       937 non-null float64
# 本益比        937 non-null float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 87.8+ KB

# %%
def multiple(n_days):
    from datetime import datetime, timedelta, timezone
    import time
    data = {}
    dt = datetime.now()
    fail_count = 0
    allow_continuous_fail_count = 15
    while len(data) < n_days:
#         print('parsing', dt.strftime('%Y%m%d'))
        try:
            # 抓資料
            data[dt.strftime('%Y%m%d')] = crawl_price(dt.strftime('%Y%m%d'))
#             print('success!')
            fail_count = 0
        except:
            # 假日爬不到
            print('{} is holiday'.format(dt.strftime('%Y%m%d')))
            fail_count += 1
            if fail_count == allow_continuous_fail_count:
                raise
                break

        # 減一天
        dt -= timedelta(days=1)
        time.sleep(10)
    return data

# %%
mul_data = multiple(5)
# Out:
# fail! 20181010 is holiday
# fail! 20181007 is holiday
# fail! 20181006 is holiday

# %%
mul_data['20181012']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-80d3c8b3df98> in <module>()
# ----> 1 mul_data['20181012']
#
# NameError: name 'mul_data' is not defined

# %%
def ohlcv(df):
    close = pd.DataFrame({k:d['收盤價'] for k,d in df.items()}).transpose()
    open_ = pd.DataFrame({k:d['開盤價'] for k,d in df.items()}).transpose()
    high = pd.DataFrame({k:d['最高價'] for k,d in df.items()}).transpose()
    low = pd.DataFrame({k:d['最低價'] for k,d in df.items()}).transpose()
    volume = pd.DataFrame({k:d['成交股數'] for k,d in df.items()}).transpose()
    for i in [close, open_, high, low, volume]:
        i.index = pd.to_datetime(i.index)
    return close, open_, high, low, volume

# %%
close, open_, high, low, volume = ohlcv(mul_data)

# %%
close
# Out:
#              1101   1102   1103   1104  1108   1109   1110   1201   1203  \
# 2018-10-12  39.00  39.00  12.65  19.25  7.20    NaN  13.95  19.90  25.15
# 2018-10-11  37.60  38.15  12.50  19.30  7.20    NaN  13.60  19.60  25.00
# 2018-10-09  40.05  39.55  13.55  20.00  7.74  14.75  13.90  20.90  25.70
# 2018-10-08  39.75  39.30  13.35  19.95  7.72  14.85  13.90  20.85  25.45
# 2018-10-05  39.70  40.15  13.40  19.95  7.80  14.95  13.95  21.05  25.35
#
#              1210  ...     9939   9940   9941   9942   9943   9944   9945  \
# 2018-10-12  34.15  ...    47.35  32.60  92.50  74.00  57.40  15.70  46.05
# 2018-10-11  34.00  ...    47.00  32.30  91.20  73.40  56.40  16.00  45.40
# 2018-10-09  36.25  ...    50.30  33.80  98.40  75.50  58.00  16.05  50.40
# 2018-10-08  36.15  ...    49.70  33.55  98.60  76.00  57.60  16.15  50.50
# 2018-10-05  36.30  ...    49.90  33.50  99.50  77.00  57.70  16.15    NaN
#
#              9946   9955   9958
# 2018-10-12  12.35  12.45  81.00
# ...

# %%
tsmc = {
    'close':close['2330'].dropna().astype(float),
    'open':open_['2330'].dropna().astype(float),
    'high':high['2330'].dropna().astype(float),
    'low':low['2330'].dropna().astype(float),
    'volume': volume['2330'].dropna().astype(float),
}

# %%
import matplotlib

# %%
tsmc.keys()
# Out:
# dict_keys(['close', 'open', 'high', 'low', 'volume'])

# %%
tsmc['close'].plot()

# %%
def save_ohlcv(df):
    s_df = df.reset_index()
    s_df_column = list(s_df.columns)
    s_df_column[0] = 'Time'
    s_df.columns = s_df_column
    return s_df

# %%
[s_close, s_open_, s_high, s_low, s_volume] = list(map(save_ohlcv, [close, open_, high, low, volume]))

# %%
s_close
# Out:
#         Time   1101   1102   1103   1104  1108   1109   1110   1201   1203  \
# 0 2018-10-12  39.00  39.00  12.65  19.25  7.20    NaN  13.95  19.90  25.15
# 1 2018-10-11  37.60  38.15  12.50  19.30  7.20    NaN  13.60  19.60  25.00
# 2 2018-10-09  40.05  39.55  13.55  20.00  7.74  14.75  13.90  20.90  25.70
# 3 2018-10-08  39.75  39.30  13.35  19.95  7.72  14.85  13.90  20.85  25.45
# 4 2018-10-05  39.70  40.15  13.40  19.95  7.80  14.95  13.95  21.05  25.35
#
#    ...     9939   9940   9941   9942   9943   9944   9945   9946   9955   9958
# 0  ...    47.35  32.60  92.50  74.00  57.40  15.70  46.05  12.35  12.45  81.00
# 1  ...    47.00  32.30  91.20  73.40  56.40  16.00  45.40  12.40  12.50  77.40
# 2  ...    50.30  33.80  98.40  75.50  58.00  16.05  50.40  13.25  13.45  86.00
# 3  ...    49.70  33.55  98.60  76.00  57.60  16.15  50.50  13.05  13.50  83.00
# 4  ...    49.90  33.50  99.50  77.00  57.70  16.15    NaN  13.00  13.50  86.00
#
# [5 rows x 942 columns]

# %%
close.reset_index()
# Out:
#        index   1101   1102   1103   1104  1108   1109   1110   1201   1203  \
# 0 2018-10-12  39.00  39.00  12.65  19.25  7.20    NaN  13.95  19.90  25.15
# 1 2018-10-11  37.60  38.15  12.50  19.30  7.20    NaN  13.60  19.60  25.00
# 2 2018-10-09  40.05  39.55  13.55  20.00  7.74  14.75  13.90  20.90  25.70
# 3 2018-10-08  39.75  39.30  13.35  19.95  7.72  14.85  13.90  20.85  25.45
# 4 2018-10-05  39.70  40.15  13.40  19.95  7.80  14.95  13.95  21.05  25.35
#
#    ...     9939   9940   9941   9942   9943   9944   9945   9946   9955   9958
# 0  ...    47.35  32.60  92.50  74.00  57.40  15.70  46.05  12.35  12.45  81.00
# 1  ...    47.00  32.30  91.20  73.40  56.40  16.00  45.40  12.40  12.50  77.40
# 2  ...    50.30  33.80  98.40  75.50  58.00  16.05  50.40  13.25  13.45  86.00
# 3  ...    49.70  33.55  98.60  76.00  57.60  16.15  50.50  13.05  13.50  83.00
# 4  ...    49.90  33.50  99.50  77.00  57.70  16.15    NaN  13.00  13.50  86.00
#
# [5 rows x 942 columns]

# %% [markdown]
# # mongo

# %%
def mongobulk(df, database, collection, Host='localhost:27017'):
    import pymongo
    myclient = pymongo.MongoClient("mongodb://{}".format(Host))
    mydb = myclient[database]
    mycol = mydb[collection]
    def pandas_generator(df):
        for record in df.to_dict(orient="records"):
            yield record
    g = pandas_generator(df)
    while True:
        try:
            mycol.insert_one(next(g))
        except StopIteration:
            print('StopIteration')
            break

# %%
mongobulk(s_close, 'stock', 'test_close')
# Out:
# StopIteration

# %%
import pymongo
myclient = pymongo.MongoClient("mongodb://{}".format('localhost:27017'))
mydb = myclient['local']

# %%
mydb.collection_names()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   """Entry point for launching an IPython kernel.
# ['startup_log']

# %%
close = mydb['close']

# %%
import datetime

# %%
dt = datetime.datetime(2018, 10, 19, 0, 0)
print(close.find_one({'_id':dt})['1101'])
dt -= datetime.timedelta(days=1)
print(close.find_one({'_id':dt})['1101'])
# Out:
# 37.25
# 38.00

# %%
dt = datetime.datetime(2018, 10, 19, 0, 0)
# print(close.find_one({'_id':dt})['1101'])
ndt = dt - datetime.timedelta(days=1)
# print(close.find_one({'_id':dt})['1101'])
dt>ndt
# Out:
# True

# %%
dt = datetime.datetime(2018, 10, 19, 0, 0)
p_1101_all = []
while dt > close.find_one(sort=[("_id", 1)])["_id"]:
#     p_1101_all.append(close.find_one({'_id':dt})['1101'])
    try:
        print(dt, close.find_one({'_id':dt})['1101'])
    except TypeError:
        print(dt, 'none')
    dt -= datetime.timedelta(days=1)
# Out:
# 2018-10-19 00:00:00 37.25
# 2018-10-18 00:00:00 38.00
# 2018-10-17 00:00:00 38.25
# 2018-10-16 00:00:00 38.20
# 2018-10-15 00:00:00 38.50
# 2018-10-14 00:00:00 none
# 2018-10-13 00:00:00 none
# 2018-10-12 00:00:00 39.00
# 2018-10-11 00:00:00 37.60
# 2018-10-10 00:00:00 none
# 2018-10-09 00:00:00 40.05
# 2018-10-08 00:00:00 39.75
# 2018-10-07 00:00:00 none
# 2018-10-06 00:00:00 none
# 2018-10-05 00:00:00 39.70
# 2018-10-04 00:00:00 39.80
# 2018-10-03 00:00:00 40.20
# 2018-10-02 00:00:00 40.30
# 2018-10-01 00:00:00 41.05
# 2018-09-30 00:00:00 none
# 2018-09-29 00:00:00 none
# 2018-09-28 00:00:00 41.10
# 2018-09-27 00:00:00 40.25
# 2018-09-26 00:00:00 39.90
# 2018-09-25 00:00:00 40.20
# 2018-09-24 00:00:00 none
# 2018-09-23 00:00:00 none
# 2018-09-22 00:00:00 none
# 2018-09-21 00:00:00 40.40
# 2018-09-20 00:00:00 40.10
# 2018-09-19 00:00:00 40.15
# 2018-09-18 00:00:00 39.70
# 2018-09-17 00:00:00 39.30
# 2018-09-16 00:00:00 none
# 2018-09-15 00:00:00 none
# 2018-09-14 00:00:00 39.65
# ...

# %%
def from_mongodb(database, collection, Host='localhost:27017'):
    import pymongo
    import pandas as pd
    myclient = pymongo.MongoClient("mongodb://{}".format(Host))
    mydb = myclient[database]
    mycol = mydb[collection]
    df = pd.DataFrame(list(mycol.find()))
    df = df.set_index('Time')
    df.drop('_id', axis=1, inplace=True)
    return df

# %%
df = from_mongodb('stock', 'test_close')

# %%
df['1101']
# Out:
# Time
# 2018-10-12    39.00
# 2018-10-11    37.60
# 2018-10-09    40.05
# 2018-10-08    39.75
# 2018-10-05    39.70
# Name: 1101, dtype: object

# %%
import pymongo
import pandas as pd
myclient = pymongo.MongoClient("mongodb://{}".format('localhost:27017'))

# %%
myclient
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
from twstock import Stock

# %%
stock = Stock('2330')

# %%
stock

# %%
a = list(zip(stock.date, stock.price))

# %%
len(a)
# Out:
# 31

# %%
stock.sid
# Out:
# '2330'

# %%
d_2016_7 = stock.fetch(2016,7)

# %%
pd.DataFrame(d_2016_7).head()
# Out:
#         date  capacity    turnover   open   high    low  close  change  \
# 0 2016-07-01  36577822  6042239175  164.5  166.0  163.5  166.0     3.5
# 1 2016-07-04  25968655  4302829364  165.5  166.5  164.5  166.0     0.0
# 2 2016-07-05  16422882  2697844648  165.0  165.5  164.0  164.0    -2.0
# 3 2016-07-06  35100107  5661722124  163.0  163.0  160.5  161.5    -2.5
# 4 2016-07-07  24442273  4009459272  163.5  165.0  163.0  164.5     3.0
#
#    transaction
# 0        13186
# 1         9484
# 2         6930
# 3        12026
# 4         9726

# %%
year = range(2016, 2019)
month = range(1, 13)
t = [(y, m) for y in year for m in month]

# %%
t = []
for y in year:
    for m in month:
        t.append((y,m))

# %%
[(y, m) for y in year for m in month]
# Out:
# [(2016, 1),
#  (2016, 2),
#  (2016, 3),
#  (2016, 4),
#  (2016, 5),
#  (2016, 6),
#  (2016, 7),
#  (2016, 8),
#  (2016, 9),
#  (2016, 10),
#  (2016, 11),
#  (2016, 12),
#  (2017, 1),
#  (2017, 2),
#  (2017, 3),
#  (2017, 4),
#  (2017, 5),
#  (2017, 6),
#  (2017, 7),
#  (2017, 8),
#  (2017, 9),
#  (2017, 10),
#  (2017, 11),
#  (2017, 12),
#  (2018, 1),
#  (2018, 2),
#  (2018, 3),
#  (2018, 4),
#  (2018, 5),
#  (2018, 6),
#  (2018, 7),
#  (2018, 8),
#  (2018, 9),
#  (2018, 10),
#  (2018, 11),
#  (2018, 12)]

# %%
total = list(d_2016_7[0]._asdict().keys())

# %%
print(total)
# Out:
# ['date', 'capacity', 'turnover', 'open', 'high', 'low', 'close', 'change', 'transaction']

# %%
d = {}
for k in total:
    d[k] = [d_2016_7[i]._asdict()[k] for i in range(len(d_2016_7))]

# %%
pd.DataFrame(d).head()
# Out:
#         date  capacity    turnover   open   high    low  close  change  \
# 0 2016-07-01  36577822  6042239175  164.5  166.0  163.5  166.0     3.5
# 1 2016-07-04  25968655  4302829364  165.5  166.5  164.5  166.0     0.0
# 2 2016-07-05  16422882  2697844648  165.0  165.5  164.0  164.0    -2.0
# 3 2016-07-06  35100107  5661722124  163.0  163.0  160.5  161.5    -2.5
# 4 2016-07-07  24442273  4009459272  163.5  165.0  163.0  164.5     3.0
#
#    transaction
# 0        13186
# 1         9484
# 2         6930
# 3        12026
# 4         9726

# %%
data_2016_7 = {k:[d_2016_7[i]._asdict()[k] for i in range(len(d_2016_7))] for k in total}
df = pd.DataFrame(data_2016_7)
df.head()
# Out:
#         date  capacity    turnover   open   high    low  close  change  \
# 0 2016-07-01  36577822  6042239175  164.5  166.0  163.5  166.0     3.5
# 1 2016-07-04  25968655  4302829364  165.5  166.5  164.5  166.0     0.0
# 2 2016-07-05  16422882  2697844648  165.0  165.5  164.0  164.0    -2.0
# 3 2016-07-06  35100107  5661722124  163.0  163.0  160.5  161.5    -2.5
# 4 2016-07-07  24442273  4009459272  163.5  165.0  163.0  164.5     3.0
#
#    transaction
# 0        13186
# 1         9484
# 2         6930
# 3        12026
# 4         9726

# %%
d_2016_1 = stock.fetch(2016,1)
data_2016_1 = {k:[d_2016_1[i]._asdict()[k] for i in range(len(d_2016_1))] for k in total}
df = pd.DataFrame(data_2016_1)
df.head()
# Out:
#         date  capacity    turnover   open   high    low  close  change  \
# 0 2016-01-04  43800291  6137797502  142.5  143.5  139.0  139.5    -3.5
# 1 2016-01-05  46502108  6436850512  139.0  140.0  137.0  138.0    -1.5
# 2 2016-01-06  53873344  7321139064  138.0  138.0  135.0  135.5    -2.5
# 3 2016-01-07  63475065  8432791819  134.5  135.0  130.5  133.0    -2.5
# 4 2016-01-08  52641383  7022206705  132.0  135.0  132.0  134.0     1.0
#
#    transaction
# 0        14188
# 1        15836
# 2        15926
# 3        19061
# 4        11784

# %%
data_2016_1
# Out:
# {'date': [datetime.datetime(2016, 1, 4, 0, 0),
#   datetime.datetime(2016, 1, 5, 0, 0),
#   datetime.datetime(2016, 1, 6, 0, 0),
#   datetime.datetime(2016, 1, 7, 0, 0),
#   datetime.datetime(2016, 1, 8, 0, 0),
#   datetime.datetime(2016, 1, 11, 0, 0),
#   datetime.datetime(2016, 1, 12, 0, 0),
#   datetime.datetime(2016, 1, 13, 0, 0),
#   datetime.datetime(2016, 1, 14, 0, 0),
#   datetime.datetime(2016, 1, 15, 0, 0),
#   datetime.datetime(2016, 1, 18, 0, 0),
#   datetime.datetime(2016, 1, 19, 0, 0),
#   datetime.datetime(2016, 1, 20, 0, 0),
#   datetime.datetime(2016, 1, 21, 0, 0),
#   datetime.datetime(2016, 1, 22, 0, 0),
#   datetime.datetime(2016, 1, 25, 0, 0),
#   datetime.datetime(2016, 1, 26, 0, 0),
#   datetime.datetime(2016, 1, 27, 0, 0),
#   datetime.datetime(2016, 1, 28, 0, 0),
#   datetime.datetime(2016, 1, 29, 0, 0),
#   datetime.datetime(2016, 1, 30, 0, 0)],
#  'capacity': [43800291,
#   46502108,
#   53873344,
#   63475065,
#   52641383,
#   48536267,
#   35133164,
# ...

# %%
from collections import defaultdict

dd = defaultdict(list)

for d in (data_2016_1, data_2016_7): # you can list as many input dicts as you want here
    for key, value in d.items():
        dd[key].extend(value)

# %%
defaultdict(list)
# Out:
# defaultdict(list, {})

# %%
list(dd.items())
# Out:
# [('date',
#   [datetime.datetime(2016, 1, 4, 0, 0),
#    datetime.datetime(2016, 1, 5, 0, 0),
#    datetime.datetime(2016, 1, 6, 0, 0),
#    datetime.datetime(2016, 1, 7, 0, 0),
#    datetime.datetime(2016, 1, 8, 0, 0),
#    datetime.datetime(2016, 1, 11, 0, 0),
#    datetime.datetime(2016, 1, 12, 0, 0),
#    datetime.datetime(2016, 1, 13, 0, 0),
#    datetime.datetime(2016, 1, 14, 0, 0),
#    datetime.datetime(2016, 1, 15, 0, 0),
#    datetime.datetime(2016, 1, 18, 0, 0),
#    datetime.datetime(2016, 1, 19, 0, 0),
#    datetime.datetime(2016, 1, 20, 0, 0),
#    datetime.datetime(2016, 1, 21, 0, 0),
#    datetime.datetime(2016, 1, 22, 0, 0),
#    datetime.datetime(2016, 1, 25, 0, 0),
#    datetime.datetime(2016, 1, 26, 0, 0),
#    datetime.datetime(2016, 1, 27, 0, 0),
#    datetime.datetime(2016, 1, 28, 0, 0),
#    datetime.datetime(2016, 1, 29, 0, 0),
#    datetime.datetime(2016, 1, 30, 0, 0),
#    datetime.datetime(2016, 7, 1, 0, 0),
#    datetime.datetime(2016, 7, 4, 0, 0),
# ...

# %%
pd.DataFrame(dd)
# Out:
#          date  capacity     turnover   open   high    low  close  change  \
# 0  2016-01-04  43800291   6137797502  142.5  143.5  139.0  139.5    -3.5
# 1  2016-01-05  46502108   6436850512  139.0  140.0  137.0  138.0    -1.5
# 2  2016-01-06  53873344   7321139064  138.0  138.0  135.0  135.5    -2.5
# 3  2016-01-07  63475065   8432791819  134.5  135.0  130.5  133.0    -2.5
# 4  2016-01-08  52641383   7022206705  132.0  135.0  132.0  134.0     1.0
# 5  2016-01-11  48536267   6430758978  133.0  134.5  130.5  133.0    -1.0
# 6  2016-01-12  35133164   4657051312  133.0  134.0  131.5  133.0     0.0
# 7  2016-01-13  50237061   6719817674  133.5  135.5  133.0  133.5     0.5
# 8  2016-01-14  39498490   5177864180  130.5  132.0  130.5  131.5    -2.0
# 9  2016-01-15  79648971  10911032870  137.5  138.0  135.5  137.0     5.5
# 10 2016-01-18  37008681   5054777797  135.0  138.0  134.5  137.0     0.0
# 11 2016-01-19  24995537   3422485906  137.5  138.0  136.0  138.0     1.0
# ...

# %%
from stock import *

# %%
df = crawl_price('20181212')

# %%
df = multiple(30)
# Out:
# 20181214 is holiday
# 20181209 is holiday
# 20181208 is holiday
# 20181202 is holiday
# 20181201 is holiday
# 20181125 is holiday
# 20181124 is holiday
# 20181118 is holiday
# 20181117 is holiday
# 20181111 is holiday
# 20181110 is holiday
# 20181104 is holiday
# 20181103 is holiday

# %%
ori_ohlcv = [close, open_, high, low, volume] = ohlcv(df)

# %%
list(close.columns)
# Out:
# ['1101',
#  '1102',
#  '1103',
#  '1104',
#  '1108',
#  '1109',
#  '1110',
#  '1201',
#  '1203',
#  '1210',
#  '1213',
#  '1215',
#  '1216',
#  '1217',
#  '1218',
#  '1219',
#  '1220',
#  '1225',
#  '1227',
#  '1229',
#  '1231',
#  '1232',
#  '1233',
#  '1234',
#  '1235',
#  '1236',
#  '1256',
#  '1262',
#  '1301',
#  '1303',
#  '1304',
#  '1305',
#  '1307',
#  '1308',
#  '1309',
#  '1310',
#  '1312',
#  '1312A',
#  '1313',
#  '1314',
#  '1315',
#  '1316',
#  '1319',
#  '1321',
#  '1323',
#  '1324',
#  '1325',
#  '1326',
#  '1337',
#  '1338',
#  '1339',
#  '1340',
#  '1402',
#  '1409',
#  '1410',
#  '1413',
#  '1414',
#  '1416',
#  '1417',
#  '1418',
#  '1419',
#  '1423',
#  '1432',
#  '1434',
#  '1435',
#  '1436',
#  '1437',
#  '1438',
#  '1439',
#  '1440',
#  '1441',
#  '1442',
#  '1443',
#  '1444',
#  '1445',
#  '1446',
#  '1447',
#  '1449',
#  '1451',
#  '1452',
#  '1453',
#  '1454',
#  '1455',
#  '1456',
#  '1457',
#  '1459',
#  '1460',
#  '1463',
#  '1464',
#  '1465',
# ...

# %%
close
# Out:
#              1101   1102   1103   1104  1108   1109   1110   1201   1203  \
# 2018-12-13  35.50  33.50  14.10  19.20  7.27  14.10  13.95  23.20  26.00
# 2018-12-12  34.95  33.15  14.05  19.20  7.30  14.10  13.85  22.80  25.75
# 2018-12-11  34.80  32.95  13.80  19.10  7.25  13.90  13.90  21.95  25.50
# 2018-12-10  34.75  33.00  13.75  19.05  7.24  14.60  13.95  22.10  25.70
# 2018-12-07  35.05  33.50  13.90  19.20  7.22  14.80  13.95  22.25  25.75
# 2018-12-06  34.65  33.15  13.80  19.10  7.17  14.50  13.90  22.25  25.55
# 2018-12-05  34.85  33.80  13.85  19.35  7.28  14.65  13.95  22.70  25.60
# 2018-12-04  35.05  33.85  14.00  19.40  7.31  14.55  14.05  22.95  25.45
# 2018-12-03  35.85  34.50  14.20  19.30  7.40  15.10  13.95  22.05  25.60
# 2018-11-30  34.50  33.70  14.10  18.95  7.40  14.90  13.90  21.80  25.35
# 2018-11-29  34.05  32.65  14.20  19.25  7.42  14.75  14.05  21.45  25.35
# 2018-11-28  34.05  33.05  13.90  19.15  7.40  14.75  14.00  21.40  25.40
# ...

# %%
from functools import reduce

# %%
df_1101 = reduce(lambda left, right:
       pd.merge(pd.DataFrame(left), pd.DataFrame(right), left_index=True, right_index=True), 
       [i['1101'] for i in [close, open_, high, low, volume]])
df_1101.columns=['close', 'open', 'high', 'low', 'volume']
df_1101
# Out:
#             close   open   high    low      volume
# 2018-12-13  35.50  34.95  35.55  34.85  12992752.0
# 2018-12-12  34.95  35.00  35.05  34.80  12970181.0
# 2018-12-11  34.80  35.10  35.35  34.80   9358961.0
# 2018-12-10  34.75  34.90  34.95  34.70   6771262.0
# 2018-12-07  35.05  34.70  35.45  34.70   9683367.0
# 2018-12-06  34.65  34.85  35.15  34.60  19811502.0
# 2018-12-05  34.85  34.50  35.30  34.35  15645678.0
# 2018-12-04  35.05  35.85  35.85  34.85  24268828.0
# 2018-12-03  35.85  34.95  36.00  34.90  26938982.0
# 2018-11-30  34.50  34.30  34.75  34.20  19459222.0
# 2018-11-29  34.05  34.45  34.60  33.95  21273973.0
# 2018-11-28  34.05  33.65  34.15  33.20  27746078.0
# 2018-11-27  33.50  33.00  33.65  32.70  75414108.0
# 2018-11-26  35.35  34.80  35.45  34.80   8757969.0
# 2018-11-23  34.70  35.00  35.00  34.50   8917654.0
# 2018-11-22  34.85  35.70  35.75  34.60  24245555.0
# 2018-11-21  35.70  36.25  36.25  35.50  22887183.0
# ...

# %%
def five(stockId):
    df = reduce(lambda left, right:
       pd.merge(pd.DataFrame(left), pd.DataFrame(right), left_index=True, right_index=True), 
       [i[stockId] for i in [close, open_, high, low, volume]])
    df.reset_index(inplace=True)
    df.columns=['timestamp', 'close', 'open', 'high', 'low', 'volume']
    df = df.sort_values(by='timestamp').reset_index(drop=True)
    return df

# %%
t = list(map(five, list(close.columns)))

# %%
t[0]
# Out:
#     timestamp  close   open   high    low      volume
# 0  2018-11-02  36.45  36.25  36.45  36.00  14967592.0
# 1  2018-11-05  35.35  36.00  36.00  35.00  18395185.0
# 2  2018-11-06  35.10  35.60  35.80  34.80  15899650.0
# 3  2018-11-07  35.50  35.30  35.75  35.30   6609546.0
# 4  2018-11-08  35.50  36.00  36.00  35.20   8155368.0
# 5  2018-11-09  34.90  35.35  35.35  34.70   8149952.0
# 6  2018-11-12  35.60  34.90  35.60  34.90   7214929.0
# 7  2018-11-13  36.40  35.00  36.40  35.00  17714261.0
# 8  2018-11-14  36.35  37.05  37.20  36.05  17880322.0
# 9  2018-11-15  36.15  36.40  36.45  36.00   7680959.0
# 10 2018-11-16  36.45  36.60  36.60  36.10   6752139.0
# 11 2018-11-19  36.50  36.50  36.65  36.15   9746930.0
# 12 2018-11-20  36.65  36.50  37.00  36.25  15633754.0
# 13 2018-11-21  35.70  36.25  36.25  35.50  22887183.0
# 14 2018-11-22  34.85  35.70  35.75  34.60  24245555.0
# 15 2018-11-23  34.70  35.00  35.00  34.50   8917654.0
# ...

# %%
data = dict(zip(list(close.columns), t))

# %%
for i in list(data.keys()):
    print('Current stock is', i)
    dtypedict = mapping_df_types(data[i])
    data[i].to_sql(name=i, con=conn, if_exists='append', index=False, dtype=dtypedict)
# Out:
# Current stock is 1101
# 2018-12-14 17:01:24,496 INFO sqlalchemy.engine.base.Engine DESCRIBE `1101`
# 2018-12-14 17:01:24,497 INFO sqlalchemy.engine.base.Engine {}
# 2018-12-14 17:01:24,501 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2018-12-14 17:01:24,505 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE `1101` (
# 	timestamp DATETIME,
# 	close NATIONAL VARCHAR(255),
# 	open NATIONAL VARCHAR(255),
# 	high NATIONAL VARCHAR(255),
# 	low NATIONAL VARCHAR(255),
# 	volume FLOAT(53)
# )
#
#
# 2018-12-14 17:01:24,507 INFO sqlalchemy.engine.base.Engine {}
# 2018-12-14 17:01:24,554 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-12-14 17:01:24,556 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-12-14 17:01:24,558 INFO sqlalchemy.engine.base.Engine INSERT INTO `1101` (timestamp, close, open, high, low, volume) VALUES (%(timestamp)s, %(close)s, %(open)s, %(high)s, %(low)s, %(volume)s)
# ...

# %%
def df_sql():
    data = dict(zip(list(close.columns), list(map(five, list(close.columns)))))
    for i in list(data.keys()):
        print('Current stock is', i)
        dtypedict = mapping_df_types(data[i])
        data[i].to_sql(name=i, con=conn, if_exists='append', index=False, dtype=dtypedict)

# %%
from pd_sql import *

# %%
Base, engine, conn, metadata = connect_sql(database='stock')
# Out:
# 2018-12-14 16:34:51,585 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2018-12-14 16:34:51,586 INFO sqlalchemy.engine.base.Engine {}
# 2018-12-14 16:34:51,616 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2018-12-14 16:34:51,618 INFO sqlalchemy.engine.base.Engine {}
# 2018-12-14 16:34:51,622 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8mb4' and `Collation` = 'utf8mb4_bin'
# 2018-12-14 16:34:51,623 INFO sqlalchemy.engine.base.Engine {}
# 2018-12-14 16:34:51,632 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2018-12-14 16:34:51,633 INFO sqlalchemy.engine.base.Engine {}
# 2018-12-14 16:34:51,634 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2018-12-14 16:34:51,635 INFO sqlalchemy.engine.base.Engine {}
# ...

# %%
a = Sql_result(conn)

# %%
a

# %%
dtypedict = mapping_df_types(data['1101'])
data['1101'].to_sql(name='stock', con=conn, if_exists='append', index=False, dtype=dtypedict)
# Out:
# 2018-12-14 16:51:01,091 INFO sqlalchemy.engine.base.Engine DESCRIBE `stock`
# 2018-12-14 16:51:01,092 INFO sqlalchemy.engine.base.Engine {}
# 2018-12-14 16:51:01,110 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2018-12-14 16:51:01,116 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE stock (
# 	timestamp DATETIME,
# 	close NATIONAL VARCHAR(255),
# 	open NATIONAL VARCHAR(255),
# 	high NATIONAL VARCHAR(255),
# 	low NATIONAL VARCHAR(255),
# 	volume FLOAT(53)
# )
#
#
# 2018-12-14 16:51:01,117 INFO sqlalchemy.engine.base.Engine {}
# 2018-12-14 16:51:01,157 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-12-14 16:51:01,160 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-12-14 16:51:01,162 INFO sqlalchemy.engine.base.Engine INSERT INTO stock (timestamp, close, open, high, low, volume) VALUES (%(timestamp)s, %(close)s, %(open)s, %(high)s, %(low)s, %(volume)s)
# ...

# %%
a.call = 'select * from `2303` limit 5'
a.get_res()
# Out:
# 2018-12-14 17:03:04,847 INFO sqlalchemy.engine.base.Engine select * from `2303` limit 5
# 2018-12-14 17:03:04,848 INFO sqlalchemy.engine.base.Engine {}
# [(datetime.datetime(2018, 11, 2, 0, 0), '11.90', '11.80', '11.90', '11.60', 71540356.0),
#  (datetime.datetime(2018, 11, 5, 0, 0), '10.75', '10.75', '11.20', '10.75', 236453269.0),
#  (datetime.datetime(2018, 11, 6, 0, 0), '10.90', '11.05', '11.20', '10.75', 211878828.0),
#  (datetime.datetime(2018, 11, 7, 0, 0), '10.95', '11.00', '11.10', '10.80', 108859652.0),
#  (datetime.datetime(2018, 11, 8, 0, 0), '10.85', '11.00', '11.00', '10.65', 154165512.0)]

# %%
# Out:
# 2018-12-14 16:51:54,836 INFO sqlalchemy.engine.base.Engine show tables
# 2018-12-14 16:51:54,837 INFO sqlalchemy.engine.base.Engine {}
# [('stock',)]
