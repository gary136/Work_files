# %%
import pandas as pd

# %%
df = pd.read_csv('./Downloads/trading_records.csv')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['訂單號碼', '訂單日期', '顧客', '電郵', '電話號碼', '商品貨號', '商品名稱', '選項', '數量', '商品特價',
#        '訂單備註', '送貨方式', '付款方式', '付款狀態', '訂單小計', '運費', '優惠折扣', '折抵購物金', '訂單合計',
#        '交易編號', '付款日期', '收件人', '收件人電話號碼', '完整地址', '管理員備註', '門市名稱',
#        '全家服務編號 / 7-11 店號'],
#       dtype='object')

# %%
eqplist = ['EQP1','EQP2','EQP3','EQP4','EQP5']

# %%
def multiple(e, time):
    def f(x):
        single = []
        for i in range(time):
            single.append(x)
        return single
    collect = list(map(f, e))
    for i in range(1, len(collect)):
        collect[0].extend(collect[i])
#         print(i)
    return collect[0]

# %%
print(multiple([1,2,3], 3))
# Out:
# [1, 1, 1, 2, 2, 2, 3, 3, 3]

# %%
print(multiple(eqplist, 25))
# Out:
# ['EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5
# ...

# %%
t
# Out:
# [['EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1'],
#  ['EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2'],
#  ['EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3'],
#  ['EQP4',
#   'EQP4',
#   'EQP4',
#   'EQP4',
#   'EQP4',
#   'EQP4',
#   'EQP4',
#   'EQP4',
# ...

# %%
def f(x):
    a = []
    for i in range(25):
        a.append(x)
    return [i for i in a]

# %%
f('EQP1')
# Out:
# ['EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1']

# %%
def f(y):
    if y>75.0:
        return 'good'
    else:
        return 'bad'
df_out['EQP'] = df_out['Yield'].apply(f)

# %%
def createLoop(num):
    mylist = range(num)
    for i in mylist:
        print(i*i)

# %%
myLoop = createLoop(3)
# Out:
# 0
# 1
# 4

# %%
def createGenerator(num):
    mylist = range(num)
    for i in mylist:
        yield i*i

# %%
mygenerator = createGenerator(3)

# %%
print(mygenerator)
# Out:
# <generator object createGenerator at 0x10f49a9e8>

# %%
for i in mygenerator:
    print(i)
# Out:
# 0
# 1
# 4

# %%
for i in mygenerator:
    print(i)

# %%
print(ord('a'),ord('b'),ord('c'))
# Out:
# 97 98 99

# %%
L = [1,2,3]
L.append([4,5,6])
L+[7,8,9]
# Out:
# [1, 2, 3, [4, 5, 6], 7, 8, 9]

# %%
L.extend([10,11,12])

# %%
L
# Out:
# [1, 2, 3, [4, 5, 6], 10, 11, 12]

# %%
import timeit
from timeit import Timer

# %%
def test1():
    l = []
    for i in range(1000):
        l = l + [i]

t1 = Timer("test1()", "from __main__ import test1")
print("concat ",t1.timeit(number=1000), "milliseconds")
# Out:
# concat  0.984126138035208 milliseconds

# %%
print(__name__)
print(__main__)
# Out:
# __main__
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ddd8e975b423> in <module>()
#       1 print(__name__)
# ----> 2 print(__main__)
#
# NameError: name '__main__' is not defined

# %%
with open('i.txt', 'a') as f:
    f.write(str('i' 'iii'))

# %%
str('i' 'iii')
# Out:
# 'iiii'

# %%
df = pd.read_csv('f100.csv')
test = df.head()
tra = test.to_dict(orient="records")

# %%
import json

# %%
tra[0]
# Out:
# {'Block': 538049,
#  'Time (UTC)': '2018-08-23T03:34:37Z',
#  'year': 2018,
#  'month': 8,
#  'date': 23,
#  'timestamp': 20180823,
#  'Amount (BTC)': -49.10277715,
#  'USD price': 6411.63,
#  'address': '1NDyJtNTjmwk5xPNhjgAMu4HDHigtobu1s',
#  'rank': 70}

# %%
json.dumps(tra[0], default=int)
# Out:
# '{"Block": 538049, "Time (UTC)": "2018-08-23T03:34:37Z", "year": 2018, "month": 8, "date": 23, "timestamp": 20180823, "Amount (BTC)": -49.10277715, "USD price": 6411.63, "address": "1NDyJtNTjmwk5xPNhjgAMu4HDHigtobu1s", "rank": 70}'

# %%
Index = 'i'
Type = 't'

# %%
def rec_to_actions(df):
    for record in df.to_dict(orient="records"):
        yield ('{ "index" : { "_index" : "%s", "_type" : "%s" }}'% (Index, Type))
        yield (json.dumps(record, default=int))

# %%
g = rec_to_actions(test)

# %%
next(g)
# Out:
# '{"Block": 538049, "Time (UTC)": "2018-08-23T03:34:37Z", "year": 2018, "month": 8, "date": 23, "timestamp": 20180823, "Amount (BTC)": -49.10277715, "USD price": 6411.63, "address": "1NDyJtNTjmwk5xPNhjgAMu4HDHigtobu1s", "rank": 70}'

# %%
i = list('abc')

# %%
t = i.pop()

# %%
t
# Out:
# 'c'

# %%
def rev_string(my_str):
    e = []
    l = list(my_str)
    while len(l)>0:
        e.append(l.pop())
    c = ''.join(e)
    return c

# %%
rev_string('attic')
# Out:
# 'citta'

# %%
print('\ni\n')
# Out:
# i

# %%
import smtplib
from email.mime.text import MIMEText
from email.utils import formataddr

# %%
my_sender='gary.li@tixguru.co'    # 发件人邮箱账号
my_pass = 'a1234567'              # 发件人邮箱密码
my_user='sarcas0705@gmail.com'      # 收件人邮箱账号，我这边发送给自己

# %%
content = "Switzerland Teams Up With Liechtenstein To Show $44 Bln Crypto ... | https://bitnewstoday.com/news/regulation/switzerland-teams-up-with-liechtenstein-to-show-44-bln-crypto-market-valuation/ \n\nSwitzerland and Israel Collaborate on Cryptocurrency & Blockchain ... | https://www.ccn.com/switzerland-and-israel-collaborate-on-cryptocurrency-blockchain-regulation/ \n\nFormer UBS bankers to set up regulated crypto-bank | https://www.ft.com/content/97bbbd30-c18b-11e8-95b1-d36dfef1b89a \n\nCrypto Fund Mulls Asian Expansion | https://www.finews.asia/finance/27594-crypto-fund-jan-brzezek-singapore-asia-expansion-finma-license \n\nCryptocurrencies: Israel enters into crypto partnership with Switzerland | https://www.euromoney.com/article/b1b9n4xg6502hd/cryptocurrencies-israel-enters-into-crypto-partnership-with-switzerland \n\nSwiss Financial Watchdog Issues Country's First Crypto Asset ... | https://cointelegraph.com/news/swiss-financial-watchdog-issues-countrys-first-crypto-asset-management-license \n\nSwitzerland Eases Crypto Regulations to Prevent Market Withdrawal | https://unhashed.com/cryptocurrency-news/switzerland-eases-crypto-regulations-prevent-market-withdrawal/ \n\nSwiss Bankers Ease Access for Crypto Startups to Prevent Mass ... | https://cointelegraph.com/news/swiss-bankers-ease-access-for-crypto-startups-to-prevent-mass-exodus \n\nSwiss springboard for Bitmain's European crypto expansion | https://www.swissinfo.ch/eng/business/cryptocurrency-giant_swiss-springboard-for-bitmain-s-european-crypto-expansion/44405096 \n\nCrypto Finance eyes Asian expansion after winning Swiss license | https://www.swissinfo.ch/eng/finma-approval_crypto-finance-eyes-asian-expansion-after-winning-swiss-license/44465638 \n\n"
msg=MIMEText(content,'plain')

# %%
msg['From']=formataddr(["FromRunoob",my_sender])  # 括号里的对应发件人邮箱昵称、发件人邮箱账号
msg['To']=formataddr(["FK",my_user])              # 括号里的对应收件人邮箱昵称、收件人邮箱账号
msg['Subject']="菜鸟教程发送邮件测试"                # 邮件的主题，也可以说是标题

# %%
server=smtplib.SMTP_SSL('smtp.gmail.com', 465)  # 发件人邮箱中的SMTP服务器，端口是25
server.login(my_sender, my_pass)  # 括号中对应的是发件人邮箱账号、邮箱密码
server.sendmail(my_sender,[my_user,],msg.as_string())  # 括号中对应的是发件人邮箱账号、收件人邮箱账号、发送邮件
server.quit()  # 关闭连接
# Out:
# (221, b'2.0.0 closing connection l129-v6sm18560377pfc.155 - gsmtp')

# %%
topic = ['crypto regulation swiss', 'stablecoin', 'security token offering', 'crypto bank']
t = [1,1,1,1]
k = list(zip(topic,t))

# %%
print(k)
# Out:
# [('crypto regulation swiss', 1), ('stablecoin', 1), ('security token offering', 1), ('crypto bank', 1)]

# %%
import pandas as pd
df = pd.read_csv('./Downloads/Keywords - Forecasts.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
# Keyword                  30 non-null object
# Estimated Clicks         30 non-null float64
# Estimated Impressions    30 non-null float64
# Estimated Cost           30 non-null float64
# Estimated CTR            30 non-null object
# Estimated Average CPC    30 non-null float64
# dtypes: float64(4), object(2)
# memory usage: 1.5+ KB

# %%
df.head()
# Out:
#            Keyword  Estimated Clicks  Estimated Impressions  Estimated Cost  \
# 0         a wallet              8.96                 150.05          141.68
# 1   airbitz wallet              0.13                  12.50            2.60
# 2    best e wallet              1.71                  75.02           25.93
# 3      best wallet             59.33                 962.80         1047.39
# 4  best wallet app              0.56                  31.26           11.38
#
#   Estimated CTR  Estimated Average CPC
# 0            6%                  15.80
# 1            1%                  20.30
# 2         2.30%                  15.14
# 3         6.20%                  17.65
# 4         1.80%                  20.19

# %%
def transform(df):
    def percent_f(x):
        x = x[:-1]
        x = float(x)
        x = x / 100
        return x
#     def f(x):
#         x = x[3:]
#         x = x.replace(',', '')
#         x = float(x)
#         return x
#     def str_float(x):
#         x = x.replace(',', '')
#         x = float(x)
#         return x
#     df.drop('Keyword Type', axis=1, inplace=True)
#     df['Estimated Cost'] = df['Estimated Cost'].apply(f)
#     df['Estimated Average CPC'] = df['Estimated Average CPC'].apply(f)
#     for i in ['Estimated Clicks', 'Estimated Impressions']:
#         df[i] = df[i].apply(str_float)
    df['Estimated CTR'] = df['Estimated CTR'].apply(percent_f)
    return df

# %%
df_num = transform(df)

# %%
df_e_click = df_num.sort_values(by=['Estimated Clicks'], ascending = False)
df_e_click
# Out:
#                   Keyword  Estimated Clicks  Estimated Impressions  \
# 26                 wallet          13478.09              249658.64
# 9             coin wallet            369.26                4288.83
# 12               e wallet            367.25                4757.73
# 8       blockchain wallet            233.22                2231.94
# 25         virtual wallet            219.58                3019.69
# 23              my wallet            150.16                2169.42
# 27             wallet app             90.04                1913.09
# 16        ethereum wallet             79.83                1050.33
# 3             best wallet             59.33                 962.80
# 24          online wallet             30.79                 387.62
# 29            xapo wallet             24.71                 262.58
# 10        coinbase wallet             18.27                 162.55
# 22           multi wallet             12.32                 312.60
# ...

# %%
df_e_click = df_num.sort_values(by=['Estimated Clicks'], ascending = False)
for i in df_e_click[df_e_click['Estimated Clicks']>1]['Keyword']:
    print(i)
# Out:
# wallet
# coin wallet
# e wallet
# blockchain wallet
# virtual wallet
# my wallet
# wallet app
# ethereum wallet
# best wallet
# online wallet
# xapo wallet
# coinbase wallet
# multi wallet
# a wallet
# easy wallet
# multi currency wallet
# e wallet app
# ledger wallet
# bittrex wallet
# bitgo wallet
# desktop wallet
# best e wallet
# electrum wallet

# %%
def sep(df, sorting_stanfard, kind, asc=True):
    df = df.sort_values(by=[sorting_stanfard], ascending=asc)
    df = df[df['Ad Group'] == kind]
    return df

# %%
f, i, c = (sep(df_num, 'Estimated Impressions', k, False) for k in ['Funds', 'Investment', 'Cryptocurrency'])

# %%
c
# Out:
#            Ad Group                            Keyword  Estimated Clicks  \
# 18   Cryptocurrency                   bitcoin currency            139.58
# 10   Cryptocurrency                        buy bitcoin            211.34
# 16   Cryptocurrency                  ethereum currency            226.60
# 13   Cryptocurrency  which cryptocurrency to invest in            135.16
# 8    Cryptocurrency                       crypto money            185.08
# 27   Cryptocurrency                       bitcoin cash            116.52
# 15   Cryptocurrency             bitcoin cryptocurrency            137.24
# 32   Cryptocurrency                  crypto currencies             53.11
# 73   Cryptocurrency                      etherium coin             17.35
# 9    Cryptocurrency                      local bitcoin            224.79
# 45   Cryptocurrency                      ethereum coin             37.47
# 62   Cryptocurrency                     bitcoin to usd             36.53
# ...

# %%
for k in f[:15]['Keyword']:
    print(k)
# Out:
# vanguard mutual funds
# fidelity mutual funds
# balanced fund
# fidelity funds
# index funds
# hedge fund
# investment fund
# equity fund
# bond funds
# american mutual funds
# money market funds
# money market mutual funds
# closed end funds
# income mutual funds
# growth fund

# %%
df['Estimated CTR'] = df['Estimated CTR'].apply(percent_f)

# %%
df_low = df.sort_values(by=['Estimated Average CPC'])

# %%
def get_words(x):
    df_low = df.sort_values(by=['Estimated Average CPC'])
    for i in df_low[df_low['Ad Group'] == x]['Keyword'][:15]:
        print(i)

# %%
def merge_words(x):
    df_low = df.sort_values(by=['Estimated Average CPC'])
    print(', '.join(df_low[df_low['Ad Group'] == x]['Keyword'][:15]))

# %%
for k in ['Funds', 'Investment', 'Cryptocurrency']:
    print('{} keywords - '.format(k))
    get_words(k)
    print('\n')
# Out:
# Funds keywords -
# buy mutual funds
# mutual fund screener
# money fund
# fidelity funds
# dividend mutual funds
# mutual funds investment
# closed end funds
# sbi mutual fund
# growth fund
# money market funds
# mutual funds in usa
# hedge fund companies
# fidelity mutual funds
# money market mutual funds
# balanced fund
#
#
# Investment keywords -
# in investing
# green investment
# alternative investments
# investment management firms
# retirement investment
# investment consultant
# global invest
# asset management
# invest invest
# fixed income investments
# financial investments
# investment securities
# investment products
# investment firms
# investment advisor
#
#
# Cryptocurrency keywords -
# btc 20
# buy bitcoin cash
# buy cryptocurrency
# buy bitcoin exchange
# cryptocurrency coins
# bitcoin currency trading
# exchange bitcoin
# ethereum currency
# btc currency
# bitcoin watch
# bitcoin cash
# eth chart
# i bitcoin
# bitcoin rate usd
# ethereum eth

# %%
for k in ['Funds', 'Investment', 'Cryptocurrency']:
    print('{} keywords - '.format(k))
    merge_words(k)
    print('\n')
# Out:
# Funds keywords -
# buy mutual funds, mutual fund screener, money fund, fidelity funds, dividend mutual funds, mutual funds investment, closed end funds, sbi mutual fund, growth fund, money market funds, mutual funds in usa, hedge fund companies, fidelity mutual funds, money market mutual funds, balanced fund
#
#
# Investment keywords -
# in investing, green investment, alternative investments, investment management firms, retirement investment, investment consultant, global invest, asset management, invest invest, fixed income investments, financial investments, investment securities, investment products, investment firms, investment advisor
#
#
# Cryptocurrency keywords -
# btc 20, buy bitcoin cash, buy cryptocurrency, buy bitcoin exchange, cryptocurrency coins, bitcoin currency trading, exchange bitcoin, ethereum currency, btc currency, bitcoin watch, bitcoin cash, eth chart, i bitcoin, bitcoin rate usd, ethereum eth

# %%
# %run send.py
# Out:
# StopIteration
# [('security token offering', 1)] @ 2018-11-07 13:39:53

# %%
import threading

# %%
threading.activeCount()
# Out:
# 5

# %%
threading.enumerate()
# Out:
# [<_MainThread(MainThread, started 140735756796800)>,
#  <Thread(Thread-2, started daemon 123145386221568)>,
#  <Heartbeat(Thread-3, started daemon 123145391476736)>,
#  <HistorySavingThread(IPythonHistorySavingThread, started 123145397805056)>,
#  <ParentPollerUnix(Thread-1, started daemon 123145403060224)>]

# %%
f = open('log')

# %%
txt = list(f)

# %%
for i in txt:
    if '.py' in i:
        print(i[17:22], i[-50:])
# Out:
# 18778 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18724 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18652 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18626 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18609 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18351 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18335 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18306 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18290 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18266 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18247 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18214 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18170 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18153 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18136 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# 18120 hon.app/Contents/MacOS/Python /Users/gary/send.py
#
# ...

# %%
for i in txt:
    if '.py' in i:
        print(i[17:22], end=' ')
# Out:
# 18778 18724 18652 18626 18609 18351 18335 18306 18290 18266 18247 18214 18170 18153 18136 18120 18099 18082 18067 18037 18021 18005 17987 17970 17954 17937 17920 17900 17883 17864 17845 17810 17782 17762 17760 17744 17727 17710 17693 17678 17660 17644 17628 17611 17594 17577 17560 17544 17527 17512 17496 17478 17461 17443 17424 17407 17390 17374 17358 17343 17328 17312 17294 17278 17260 17245 17229 17210 17194 17178 17160 17143 17123 17107 17092 17074 17058 17040 17020 17003 16986 16968 16943 16924 16896 16882 16866 16851 16835 16812 16791 16773 16757 16741 16688 16681 16652 16638 16622 16606 15262 14056 13173 12951 11452  9639  7752  5675  3663  2332  1110 99541 98641 83475 81565 79840 78220 50013

# %%
df=pd.Series(["1","a",1,True])

# %%
df
# Out:
# 0       1
# 1       a
# 2       1
# 3    True
# dtype: object

# %%
df.apply(type)
# Out:
# 0     <class 'str'>
# 1     <class 'str'>
# 2     <class 'int'>
# 3    <class 'bool'>
# dtype: object

# %%
# %timeit df.apply(type)
# Out:
# 160 µs ± 22.8 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
df = pd.read_csv('./Downloads/F - 工作表1.csv')

# %%
df['公司'].drop_duplicates()
# Out:
# 0       1437 勤益控
# 34       2302 麗正
# 68       2303 聯電
# 102     2311 日月光
# 150      2325 矽品
# 184     2330 台積電
# 225      2337 旺宏
# 259      2338 光罩
# 293      2342 茂矽
# 327     2344 華邦電
# 361      2351 順德
# 395      2363 矽統
# 429      2379 瑞昱
# 463      2401 凌陽
# 497     2436 偉詮電
# 531      5305 敦南
# 565     2301 光寶科
# 599      2305 全友
# 642      2324 仁寶
# 676     2352 佳世達
# 718      2353 宏碁
# 752     2356 英業達
# 786      2358 廷鑫
# 820      2362 藍天
# 854      2365 昆盈
# 888      2376 技嘉
# 922      2417 圓剛
# 956      2425 承啟
# 990      9912 偉聯
# 1024     2323 中環
#           ...
# 1597     2375 智寶
# 1631    2383 台光電
# 1665     2415 錩新
# 1699     2420 新巨
# 1733     2421 建準
# 1767     2431 聯昌
# 1801    2462 良得電
# 1835     2476 鉅祥
# 1869    2492 華新科
# 1903     3021 鴻名
# 1937    6191 精成科
# 1971     2347 聯強
# 2005     2430 燦坤
# 2039    2427 三商電
# 2073     2453 凌群
# 2107     2468 華經
# 2141     2471 資通
# 2175    2480 敦陽科
# 2209     3029 零壹
# 2243     5203 訊連
# 2277     6112 聚碩
# ...

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df.head()
# Out:
#          公司          年月  產業別             DA   經理人持股    董事持股   監察人持股  外資總投資股率  \
# 0  1437 勤益控   6/29/2001    1    679,269.13   0.0606  0.2472  0.1787   0.0191
# 1  1437 勤益控  12/31/2001    1  1,078,619.22   0.0593  0.2460  0.1787   0.0191
# 2  1437 勤益控   6/28/2002    1    486,535.55   0.0593  0.2460  0.0086   0.0191
# 3  1437 勤益控  12/31/2002    1  1,375,473.24   0.0000  0.2450  0.0086   0.0191
# 4  1437 勤益控   6/30/2003    1    657,275.41   0.0006  0.2462  0.0086   0.0195
#
#     投信持股率  自營持股率    營收成長率    公司規模   負債比率％   資產週轉率       ROE     財務槓桿      營運槓桿
# 0  0.0000    0.0  0.4050   6.4905  0.3310  0.1027  (3.7800)  0.8210     (8.99)
# 1  0.0000    0.0  0.0711   6.5059  0.3618  0.2266  (6.5600)  0.7776     (2.22)
# 2  0.0000    0.0  0.2712   6.5117  0.3925  0.1243  (1.6700)  0.4969    (54.94)
# 3  0.0000    0.0  0.3039   6.5925  0.4636  0.2420   2.8800   0.4217    (16.98)
# 4  0.0297    0.0  0.4569   6.5930  0.4889  0.1502  (2.1900)  0.0606   (628.56)

# %%
print(list(df.columns))
# Out:
# ['公司', '年月', '產業別', 'DA', '經理人持股', '董事持股', '監察人持股', '外資總投資股率', '投信持股率', '自營持股率', '營收成長率', '公司規模', '負債比率％', '資產週轉率', ' ROE', '財務槓桿', '營運槓桿']

# %%
df_x = df[['經理人持股', '董事持股', '監察人持股', '外資總投資股率', '投信持股率', '自營持股率', '營收成長率', '公司規模', '負債比率％', '資產週轉率', ' ROE', '財務槓桿', '營運槓桿']]
df_x.head()
# Out:
#     經理人持股    董事持股   監察人持股  外資總投資股率   投信持股率  自營持股率    營收成長率    公司規模   負債比率％  \
# 0  0.0606  0.2472  0.1787   0.0191  0.0000    0.0  0.4050   6.4905  0.3310
# 1  0.0593  0.2460  0.1787   0.0191  0.0000    0.0  0.0711   6.5059  0.3618
# 2  0.0593  0.2460  0.0086   0.0191  0.0000    0.0  0.2712   6.5117  0.3925
# 3  0.0000  0.2450  0.0086   0.0191  0.0000    0.0  0.3039   6.5925  0.4636
# 4  0.0006  0.2462  0.0086   0.0195  0.0297    0.0  0.4569   6.5930  0.4889
#
#     資產週轉率       ROE     財務槓桿      營運槓桿
# 0  0.1027  (3.7800)  0.8210     (8.99)
# 1  0.2266  (6.5600)  0.7776     (2.22)
# 2  0.1243  (1.6700)  0.4969    (54.94)
# 3  0.2420   2.8800   0.4217    (16.98)
# 4  0.1502  (2.1900)  0.0606   (628.56)

# %%
df_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2617 entries, 0 to 2616
# Data columns (total 13 columns):
# 經理人持股      2617 non-null float64
# 董事持股       2617 non-null float64
# 監察人持股      2617 non-null float64
# 外資總投資股率    2617 non-null float64
# 投信持股率      2617 non-null float64
# 自營持股率      2617 non-null float64
# 營收成長率      2617 non-null object
# 公司規模       2617 non-null float64
# 負債比率％      2617 non-null float64
# 資產週轉率      2617 non-null float64
#  ROE       2617 non-null object
# 財務槓桿       2617 non-null object
# 營運槓桿       2617 non-null object
# dtypes: float64(9), object(4)
# memory usage: 265.9+ KB

# %%
def f(x):
    rule_f = {ord(c):None for c in ' ,'}
    x = x.translate(rule_f)
    rule_negative = {ord(c):None for c in '()'}
    if ')' in x:
        x = '-'+x.translate(rule_negative)
    return float(x)

# %%
for i in ['營收成長率', ' ROE', '財務槓桿', '營運槓桿']:
    df_x[i] = df_x[i].apply(f)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_x.head()
# Out:
#     經理人持股    董事持股   監察人持股  外資總投資股率   投信持股率  自營持股率   營收成長率    公司規模   負債比率％  \
# 0  0.0606  0.2472  0.1787   0.0191  0.0000    0.0  0.4050  6.4905  0.3310
# 1  0.0593  0.2460  0.1787   0.0191  0.0000    0.0  0.0711  6.5059  0.3618
# 2  0.0593  0.2460  0.0086   0.0191  0.0000    0.0  0.2712  6.5117  0.3925
# 3  0.0000  0.2450  0.0086   0.0191  0.0000    0.0  0.3039  6.5925  0.4636
# 4  0.0006  0.2462  0.0086   0.0195  0.0297    0.0  0.4569  6.5930  0.4889
#
#     資產週轉率   ROE    財務槓桿    營運槓桿
# 0  0.1027 -3.78  0.8210   -8.99
# 1  0.2266 -6.56  0.7776   -2.22
# 2  0.1243 -1.67  0.4969  -54.94
# 3  0.2420  2.88  0.4217  -16.98
# 4  0.1502 -2.19  0.0606 -628.56

# %%
df_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2617 entries, 0 to 2616
# Data columns (total 13 columns):
# 經理人持股      2617 non-null float64
# 董事持股       2617 non-null float64
# 監察人持股      2617 non-null float64
# 外資總投資股率    2617 non-null float64
# 投信持股率      2617 non-null float64
# 自營持股率      2617 non-null float64
# 營收成長率      2617 non-null float64
# 公司規模       2617 non-null float64
# 負債比率％      2617 non-null float64
# 資產週轉率      2617 non-null float64
#  ROE       2617 non-null float64
# 財務槓桿       2617 non-null float64
# 營運槓桿       2617 non-null float64
# dtypes: float64(13)
# memory usage: 265.9 KB

# %%
df_y = df['DA']
df_y.head()
# Out:
# 0      679,269.13
# 1    1,078,619.22
# 2      486,535.55
# 3    1,375,473.24
# 4      657,275.41
# Name: DA, dtype: object

# %%
df_y = df_y.apply(f)

# %%
df_y.head()
# Out:
# 0     679269.13
# 1    1078619.22
# 2     486535.55
# 3    1375473.24
# 4     657275.41
# Name: DA, dtype: float64

# %%
lm = LinearRegression()
lm.fit(df_x, df_y)
res = lm.coef_

# %%
dict(zip(df_x.columns, res))
# Out:
# {'經理人持股': -149171403.39076278,
#  '董事持股': 118463794.67735386,
#  '監察人持股': -55983525.1545269,
#  '外資總投資股率': 197855920.25445506,
#  '投信持股率': -256321737.01599956,
#  '自營持股率': -2807671359.1841025,
#  '營收成長率': 22248630.117884252,
#  '公司規模': 116436636.84101579,
#  '負債比率％': -368152637.9907823,
#  '資產週轉率': 30385553.359131556,
#  ' ROE': -591633.5111224994,
#  '財務槓桿': 41578.728397386454,
#  '營運槓桿': -436.610364815166}

# %%
import pandas as pd
from rpy2.robjects import r, pandas2ri
pandas2ri.activate()

# %%
file = 'Downloads/nyse.RData'
rf = r['load'](file)

# %%
head(rf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-243-ab8d8331878f> in <module>()
# ----> 1 head(rf)
#
# NameError: name 'head' is not defined

# %%
from rpy2.robjects.vectors import StrVector, IntVector, ListVector, DataFrame

# %%
dir(rf)
# Out:
# ['NAvalue',
#  '_RObjectMixin__close',
#  '_RObjectMixin__fifo',
#  '_RObjectMixin__file',
#  '_RObjectMixin__rclass',
#  '_RObjectMixin__rclass_set',
#  '_RObjectMixin__readlines',
#  '_RObjectMixin__show',
#  '_RObjectMixin__sink',
#  '_RObjectMixin__slots',
#  '_RObjectMixin__tempfile',
#  '_RObjectMixin__unlink',
#  '__add__',
#  '__array_struct__',
#  '__class__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getslice__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__repr_content__',
#  '__rname__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sexp__',
#  '__sexp_refcount__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
# ...

# %%
rf.__reduce__()
# Out:
# (<function copyreg._reconstructor(cls, base, state)>,
#  (rpy2.robjects.vectors.StrVector,
#   rpy2.rinterface.StrSexpVector,
#   <rpy2.rinterface.StrSexpVector - Python:0x11d55c678 / R:0x7f939a7619c8>),
#  (b'X\n\x00\x00\x00\x02\x00\x03\x05\x01\x00\x02\x03\x00\x00\x00\x00\x10\x00\x00\x00\x01\x00\x04\x00\t\x00\x00\x00\x04nyse',
#   {'ro': <rpy2.robjects.vectors.VectorOperationsDelegator at 0x120887898>,
#    'rx': <rpy2.robjects.vectors.ExtractDelegator at 0x120887860>,
#    'rx2': <rpy2.robjects.vectors.DoubleExtractDelegator at 0x11d429780>}))

# %%
a = r('c(1,2,3)')
print(a)
# Out:
# [1. 2. 3.]

# %%
import pandas as pd

# %%
df = pd.read_csv('nyse.csv')

# %%
from datetime import datetime

# %%
df['Date'] = df['Date'].apply(lambda x:datetime.strptime(x, '%Y-%m-%d'))

# %%
df.index = df['Date']

# %%
import matplotlib.pyplot as plt

# %%
fig, ax1 = plt.subplots(figsize=(12,4))
ax1.plot(df['GOOGL'], label='GOOGL', color = 'k')
ax1.set_ylabel('GOOGL')
ax1.set_xlabel('date')
ax2 = ax1.twinx()  # this is the important function
ax2.plot(df['AAPL'], label='AAPL', color = 'r')
ax2.set_ylabel('AAPL')
fig.legend()

# %%
def twin(data_y1, data_y2, *args, color_1 = 'k', color_2 = 'r'):
    import matplotlib.pyplot as plt
    fig, ax1 = plt.subplots(figsize=(12,4))
    ax2 = ax1.twinx()  # this is the important function
    if len(args) > 0:
        ax1.plot(data_y1, label=args[0], color = 'k')
        ax1.set_ylabel(args[0])
        ax1.set_xlabel(args[1])
        ax2.plot(data_y2, label=args[2], color = 'r')
        ax2.set_ylabel(args[2])
        fig.legend()
    else:
        ax1.plot(data_y1, color = 'k')
        ax2.plot(data_y2, color = 'r')
        fig.legend()

# %%
i = twin(df['GOOGL'], df['AAPL'], 'GOOGL', 'date', 'AAPL')

# %%
dir(i)
# Out:
# ['__bool__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
dir(ax1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_text',
#  '_adjustable',
#  '_agg_filter',
#  '_alpha',
#  '_anchor',
#  '_animated',
#  '_aspect',
#  '_autoscaleXon',
#  '_autoscaleYon',
#  '_axes',
#  '_axes_class',
#  '_axes_locator',
#  '_axisbelow',
#  '_cachedRenderer',
#  '_clipon',
#  '_clippath',
#  '_connected',
#  '_contains',
#  '_current_image',
#  '_facecolor',
#  '_frameon',
#  '_gci',
#  '_gen_axes_patch',
#  '_gen_axes_spines',
#  '_get_axis_list',
#  '_get_lines',
#  '_get_patches_for_fill',
#  '_get_view',
#  '_gid',
#  '_gridOn',
#  '_hold',
# ...

# %%
help(ax1.plot)
# Out:
# Help on method plot in module matplotlib.axes._axes:
#
# plot(*args, data=None, **kwargs) method of matplotlib.axes._subplots.AxesSubplot instance
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...
