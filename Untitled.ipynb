# %%
import pandas as pd

# %%
df = pd.read_csv('./Downloads/trading_records.csv')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['訂單號碼', '訂單日期', '顧客', '電郵', '電話號碼', '商品貨號', '商品名稱', '選項', '數量', '商品特價',
#        '訂單備註', '送貨方式', '付款方式', '付款狀態', '訂單小計', '運費', '優惠折扣', '折抵購物金', '訂單合計',
#        '交易編號', '付款日期', '收件人', '收件人電話號碼', '完整地址', '管理員備註', '門市名稱',
#        '全家服務編號 / 7-11 店號'],
#       dtype='object')

# %%
df[['訂單日期', '商品名稱', '選項', '數量', '商品特價',
       '訂單備註', '送貨方式', '付款方式', '付款狀態', '訂單小計', '運費', '優惠折扣', '折抵購物金', '訂單合計',
       '交易編號', '付款日期', '完整地址', '管理員備註']]
# Out:
#                      訂單日期                               商品名稱    選項  數量  商品特價  \
# 0     2018-01-02 17:36:21     NabShop V領長版單扣西裝外套*4色 【540008】   灰 F   1   820
# 1     2018-01-02 22:43:32    NabShop 雙鈕扣造型西裝長版外套*3色 【580031】  咖啡 F   1   820
# 2     2018-01-02 22:43:32  NabShop 兩件式條紋上衣+背心裙套裝*3色 【290003】     棕   1   520
# 3     2018-01-04 12:39:04     NabShop 鬆緊皮釦造型粗跟短靴*黑色 【670024】  黑 36   1   990
# 4     2018-01-04 22:48:43       NabShop 中領條文合身上衣*3色 【170107】  深卡 F   1   247
# 5     2018-01-04 22:48:43     NabShop 長版粗針織雙口袋背心*5色 【240046】    墨綠   1   450
# 6     2018-01-04 22:48:43     NabShop 照片女孩簡約長袖上衣*白色 【170115】   白 F   1   330
# 7     2018-01-04 22:48:43        NabShop 傘狀鬆緊長寬褲*3色 【470030】   橘 F   1   550
# 8     2018-01-04 22:48:43       NabShop 可拆吊帶排扣長褲*2色 【470067】  軍綠 F   1   532
# 9     2018-01-04 22:48:43       NabShop 粉嫩撞色針織上衣*3色 【170081】   灰 F   1   523
# 10    2018-01-05 16:51:26     NabShop 鬆緊皮釦造型粗跟短靴*黑色 【670024】  黑 36   1   990
# ...

# %%
eqplist = ['EQP1','EQP2','EQP3','EQP4','EQP5']

# %%
def multiple(e, time):
    def f(x):
        single = []
        for i in range(time):
            single.append(x)
        return single
    collect = list(map(f, e))
    for i in range(1, len(collect)):
        collect[0].extend(collect[i])
#         print(i)
    return collect[0]

# %%
print(multiple([1,2,3], 3))
# Out:
# [1, 1, 1, 2, 2, 2, 3, 3, 3]

# %%
print(multiple(eqplist, 25))
# Out:
# ['EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP1', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP2', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP3', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP4', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5', 'EQP5
# ...

# %%
t
# Out:
# [['EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1',
#   'EQP1'],
#  ['EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2',
#   'EQP2'],
#  ['EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3',
#   'EQP3'],
#  ['EQP4',
#   'EQP4',
#   'EQP4',
#   'EQP4',
#   'EQP4',
#   'EQP4',
#   'EQP4',
#   'EQP4',
# ...

# %%
def f(x):
    a = []
    for i in range(25):
        a.append(x)
    return [i for i in a]

# %%
f('EQP1')
# Out:
# ['EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1',
#  'EQP1']

# %%
def f(y):
    if y>75.0:
        return 'good'
    else:
        return 'bad'
df_out['EQP'] = df_out['Yield'].apply(f)

# %%
def createLoop(num):
    mylist = range(num)
    for i in mylist:
        print(i*i)

# %%
myLoop = createLoop(3)
# Out:
# 0
# 1
# 4

# %%
def createGenerator(num):
    mylist = range(num)
    for i in mylist:
        yield i*i

# %%
mygenerator = createGenerator(3)

# %%
print(mygenerator)
# Out:
# <generator object createGenerator at 0x10f49a9e8>

# %%
for i in mygenerator:
    print(i)
# Out:
# 0
# 1
# 4

# %%
for i in mygenerator:
    print(i)

# %%
print(ord('a'),ord('b'),ord('c'))
# Out:
# 97 98 99

# %%
L = [1,2,3]
L.append([4,5,6])
L+[7,8,9]
# Out:
# [1, 2, 3, [4, 5, 6], 7, 8, 9]

# %%
L.extend([10,11,12])

# %%
L
# Out:
# [1, 2, 3, [4, 5, 6], 10, 11, 12]

# %%
import timeit
from timeit import Timer

# %%
def test1():
    l = []
    for i in range(1000):
        l = l + [i]

t1 = Timer("test1()", "from __main__ import test1")
print("concat ",t1.timeit(number=1000), "milliseconds")
# Out:
# concat  0.984126138035208 milliseconds

# %%
print(__name__)
print(__main__)
# Out:
# __main__
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ddd8e975b423> in <module>()
#       1 print(__name__)
# ----> 2 print(__main__)
#
# NameError: name '__main__' is not defined

# %%
with open('i.txt', 'a') as f:
    f.write(str('i' 'iii'))

# %%
str('i' 'iii')
# Out:
# 'iiii'

# %%
df = pd.read_csv('f100.csv')
test = df.head()
tra = test.to_dict(orient="records")

# %%
import json

# %%
tra[0]
# Out:
# {'Block': 538049,
#  'Time (UTC)': '2018-08-23T03:34:37Z',
#  'year': 2018,
#  'month': 8,
#  'date': 23,
#  'timestamp': 20180823,
#  'Amount (BTC)': -49.10277715,
#  'USD price': 6411.63,
#  'address': '1NDyJtNTjmwk5xPNhjgAMu4HDHigtobu1s',
#  'rank': 70}

# %%
json.dumps(tra[0], default=int)
# Out:
# '{"Block": 538049, "Time (UTC)": "2018-08-23T03:34:37Z", "year": 2018, "month": 8, "date": 23, "timestamp": 20180823, "Amount (BTC)": -49.10277715, "USD price": 6411.63, "address": "1NDyJtNTjmwk5xPNhjgAMu4HDHigtobu1s", "rank": 70}'

# %%
Index = 'i'
Type = 't'

# %%
def rec_to_actions(df):
    for record in df.to_dict(orient="records"):
        yield ('{ "index" : { "_index" : "%s", "_type" : "%s" }}'% (Index, Type))
        yield (json.dumps(record, default=int))

# %%
g = rec_to_actions(test)

# %%
next(g)
# Out:
# '{"Block": 538049, "Time (UTC)": "2018-08-23T03:34:37Z", "year": 2018, "month": 8, "date": 23, "timestamp": 20180823, "Amount (BTC)": -49.10277715, "USD price": 6411.63, "address": "1NDyJtNTjmwk5xPNhjgAMu4HDHigtobu1s", "rank": 70}'

# %%
i = list('abc')

# %%
t = i.pop()

# %%
t
# Out:
# 'c'

# %%
def rev_string(my_str):
    e = []
    l = list(my_str)
    while len(l)>0:
        e.append(l.pop())
    c = ''.join(e)
    return c

# %%
rev_string('attic')
# Out:
# 'citta'

# %%
print('\ni\n')
# Out:
# i
