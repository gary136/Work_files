# %%
# %run bitinfocharts.py
# Out:
# program starts @ Thu Oct  4 12:33:04 2018
# connects with elasticsearch @ Thu Oct  4 12:33:04 2018
# over @ Thu Oct  4 12:33:04 2018
# none updated data
# program ceased temporarily @ Thu Oct  4 12:36:20 2018
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/bitinfocharts.py in <module>()
#     181             print('none updated data')
#     182         print('program ceased temporarily @ {}'.format(time.asctime(time.localtime())))
# --> 183         time.sleep(1800)
#     184         print('sleep finishing @ {}'.format(time.asctime(time.localtime())))
#
# KeyboardInterrupt:

# %%
from technical import *
from pd_ela import *
import pandas as pd
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df_sum = pd.read_csv('f100_1070911.csv')

# %%
df_sum
# Out:
#         Block            Time (UTC)  year  month  date  timestamp  \
# 0      540930  2018-09-11T09:43:10Z  2018      9    11   20180911
# 1      540929  2018-09-11T09:21:04Z  2018      9    11   20180911
# 2      540928  2018-09-11T09:01:49Z  2018      9    11   20180911
# 3      540926  2018-09-11T08:49:04Z  2018      9    11   20180911
# 4      540925  2018-09-11T08:28:00Z  2018      9    11   20180911
# 5      540924  2018-09-11T08:14:21Z  2018      9    11   20180911
# 6      540922  2018-09-11T07:56:58Z  2018      9    11   20180911
# 7      540919  2018-09-11T07:36:40Z  2018      9    11   20180911
# 8      540918  2018-09-11T07:24:01Z  2018      9    11   20180911
# 9      540918  2018-09-11T07:24:01Z  2018      9    11   20180911
# 10     540918  2018-09-11T07:24:01Z  2018      9    11   20180911
# 11     540917  2018-09-11T07:08:12Z  2018      9    11   20180911
# 12     540915  2018-09-11T07:02:33Z  2018      9    11   20180911
# ...

# %%
df_technical = tech(df_sum)

# %%
df_technical.head(15)
# Out:
#               Time (UTC)  timestamp  Amount (BTC)   USD price      RSI_6  \
# 0   2015-01-04T00:00:00Z   20150104    186.460273  282.470000        NaN
# 1   2015-01-05T00:00:00Z   20150105     50.000000  269.970000        NaN
# 2   2015-01-06T00:00:00Z   20150106    550.000000  277.801250        NaN
# 3   2015-01-07T00:00:00Z   20150107   1594.032581  285.063333        NaN
# 4   2015-01-08T00:00:00Z   20150108    100.000000  286.555000        NaN
# 5   2015-01-09T00:00:00Z   20150109    300.000000  284.535000        NaN
# 6   2015-01-10T00:00:00Z   20150110   4800.000000  281.093333  79.294081
# 7   2015-01-11T00:00:00Z   20150111    600.000000  273.156667  48.348912
# 8   2015-01-12T00:00:00Z   20150112    222.598089  268.430000  46.396492
# 9   2015-01-13T00:00:00Z   20150113   1742.267937  236.608571  55.148201
# 10  2015-01-14T00:00:00Z   20150114   3450.000000  192.825714  63.241249
# 11  2015-01-15T00:00:00Z   20150115   4114.826551  197.377857  66.098940
# ...

# %%
Host = '35.194.152.180' 
Index = 'btc_tech' 
Type = 't'

# %%
create(Host, Index, Type)
# Out:
# created

# %%
esbulk(Host, Index, Type, df_technical)
# Out:
# False

# %%
es = Elasticsearch([Host], timeout=30)

# %%
es.search(index="btc_top100_index", body={"query": {"match": {'Time (UTC)':'2015-01-04T00:54:23Z'}}})
# Out:
# {'took': 8,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': 1,
#   'max_score': 1.0,
#   'hits': [{'_index': 'btc_top100_index',
#     '_type': 't',
#     '_id': '_5gTyGUB3n6arYnVKO4Z',
#     '_score': 1.0,
#     '_source': {'Block': 337355,
#      'Time (UTC)': '2015-01-04T00:54:23Z',
#      'year': 2015,
#      'month': 1,
#      'date': 4,
#      'timestamp': 20150104,
#      'Amount (BTC)': 186.46027276,
#      'Balance (BTC)': 2411.08140078,
#      'Balance (USD)': 681051.0,
#      'USD price': 282.47,
#      'address': '1J7fmT3Wv62u4p6FuwbVJQXhQE3HiH4AQs',
#      'rank': 47}}]}}
